# %% [markdown]
# # LineageOT benchmark

# %%
# pip install git+https://github.com/aforr/LineageOT@master cvxopt

# %%
from jax.config import config
config.update("jax_enable_x64", True)

from ott.geometry.geometry import Geometry
from ott.geometry.pointcloud import PointCloud
from jax import numpy as jnp
import seaborn as sns

from time import perf_counter
from moscot import FusedGW, Unbalanced, GW
from copy import deepcopy
import pickle
import os

# %%
import copy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import ot
import networkx as nx

import lineageot.simulation as sim
import lineageot.evaluation as sim_eval
import lineageot.inference as sim_inf

from typing import Literal, Optional, Sequence, Dict
import traceback
from collections import namedtuple, defaultdict

# %%
bnt = namedtuple("bnt", "tmat early_cost late_cost norm_diff converged time")
stn = namedtuple("sim",
                 "sim_info "
                 "ancestor_info "
                 "rna_arrays "
                 "true_coupling "
                 "true_distances "
                 "barcode_arrays "
                 "fitted_tree_distances_early "
                 "fitted_tree_distances_late "
                 "hamming_distances_late "
                 "early_time_rna_cost "
                 "late_time_rna_cost "
                 "true_trees "
                 "fitted_trees ")

# %%
def create_geometry(cost_matrix: np.ndarray, scale='max') -> Geometry:
    cost_matrix = jnp.array(cost_matrix)
    if scale is None:
        pass
    elif scale == 'max':
        cost_matrix /= cost_matrix.max()
        assert cost_matrix.max() == 1.0
    elif scale == 'mean':
        cost_matrix /= np.mean(cost_matrix)
    elif scale == 'median':
        cost_matrix /= np.median(cost_matrix)
    else:
        raise NotImplementedError(scale)
        
    assert (cost_matrix >= 0).all()
    return Geometry(cost_matrix=cost_matrix)


def fgw_solver(C1, C2, C12, alpha=0, epsilon=1e-2, loss_fun='square_loss',
              p=None, q=None, max_iterations=100, rtol=1e-9, atol=1e-9, verbose=False):
    
    from ot.gromov import init_matrix, gwggrad, gwloss
    
    assert 0 <= alpha <= 1, alpha
    
    if p is None:
        p = np.ones((C1.shape[0],), dtype=np.float64) / C1.shape[0]
    if q is None:
        q = np.ones((C2.shape[0],), dtype=np.float64) / C2.shape[0]

    solver = ot.sinkhorn if epsilon >= 0.1 else ot.bregman.sinkhorn_epsilon_scaling
    C1 = np.asarray(C1, dtype=np.float64)
    C2 = np.asarray(C2, dtype=np.float64)
    
    if alpha == 0:
        C12 = np.asarray(C12, dtype=np.float64)
        return solver(p, q, C12, reg=epsilon, numItermax=max_iterations, stopThr=rtol)
    if alpha == 1:
        return ot.gromov.entropic_gromov_wasserstein(C1, C2, p=p, q=q, loss_fun=loss_fun, epsilon=epsilon, tol=rtol)

    C12 = np.asarray(C12, dtype=np.float64)
    C12 = (1 - alpha) * C12
    f_val = 0
    T = np.outer(p, q)
    constC, hC1, hC2 = init_matrix(C1, C2, p, q, loss_fun)
    
    
    fmt = "{:5s}|{:12s}|{:8s}|{:8s}"
    if verbose:
        print(
            fmt.format(
                "It.",
                "Loss",
                "Rel. loss   ",
                "Abs. loss   ",
            )
            + "\n"
            + "-" * 83
        )
    
    for i in range(max_iterations):
        old_fval = f_val

        # compute the gradient
        tens = C12 + alpha * gwggrad(constC, hC1, hC2, T)
        T = solver(p, q, tens, reg=epsilon)
        
        f_val = gwloss(constC, hC1, hC2, T)
        abs_delta_fval = abs(f_val - old_fval)
        relative_delta_fval = abs_delta_fval / abs(f_val)
        
        if verbose:
            print(
                f"{i + 1:5d}|{f_val:8e}|{relative_delta_fval:8e}|{abs_delta_fval:8e}"
            )
        
        if relative_delta_fval <= rtol or abs_delta_fval <= atol:
            break
    
    return T

# %%
def init_sim(flow_type: Literal['bifurcation', 'convergent', 'partial_convergent', 'mistmatched_clusters'],
             seed: int = 257, plot: bool = True, **kwargs):
    fpath = f"{flow_type}_sim.pickle"
    if os.path.isfile(fpath):
        with open(fpath, "rb") as fin:
            return pickle.load(fin)
    
    start = perf_counter()
    np.random.seed(seed) 
    if flow_type == 'bifurcation':
        timescale = 1
    else:
        timescale = 100

    x0_speed = 1/timescale
    sim_params = sim.SimulationParameters(division_time_std = 0.01*timescale,
                                          flow_type = flow_type,
                                          x0_speed = x0_speed,
                                          mutation_rate = 1/timescale,
                                          mean_division_time = 1.1*timescale,
                                          timestep = 0.001*timescale,
                                          **kwargs)

    # These parameters can be adjusted freely.
    # As is, they replicate the plots in the paper for the fully convergent simulation.
    mean_x0_early = 2
    time_early = 7.4*timescale # Time when early cells are sampled
    time_late = time_early + 4*timescale # Time when late cells are sampled
    x0_initial = mean_x0_early -time_early*x0_speed
    initial_cell = sim.Cell(np.array([x0_initial, 0, 0]), np.zeros(sim_params.barcode_length))
    sample_times = {'early' : time_early, 'late' : time_late}



    # Choosing which of the three dimensions to show in later plots
    if flow_type == 'mismatched_clusters':
        dimensions_to_plot = [1, 2]
    else:
        dimensions_to_plot = [0, 1]

    ## Running the simulation
    sample = sim.sample_descendants(initial_cell.deepcopy(), time_late, sim_params)

    # Extracting trees and barcode matrices
    true_trees = {'late': sim_inf.list_tree_to_digraph(sample)}
    true_trees['late'].nodes['root']['cell'] = initial_cell
    true_trees['early'] = sim_inf.truncate_tree(true_trees['late'], sample_times['early'], sim_params)

    # Computing the ground-truth coupling
    true_coupling = sim_inf.get_true_coupling(true_trees['early'], true_trees['late'])
    
    data_arrays = {'late': sim_inf.extract_data_arrays(true_trees['late']),
                   'early': sim_inf.extract_data_arrays(true_trees['early'])}
    rna_arrays = {'late': data_arrays['late'][0]}
    barcode_arrays = {'early': data_arrays['early'][1], 'late': data_arrays['late'][1]}

    rna_arrays['early'] = sim_inf.extract_data_arrays(true_trees['early'])[0]
    num_cells = {'early': rna_arrays['early'].shape[0], 'late': rna_arrays['late'].shape[0]}

    print("Times:", sample_times)
    print("Number of cells:", num_cells)
    
        # Creating a copy of the true tree for use in LineageOT
    true_trees['late, annotated'] = copy.deepcopy(true_trees['late'])
    sim_inf.add_node_times_from_division_times(true_trees['late, annotated'])

    sim_inf.add_nodes_at_time(true_trees['late, annotated'], sample_times['early'])
    
    if plot:
        # Scatter plot of cell states
        cmap = "coolwarm"
        colors = [plt.get_cmap(cmap)(0), plt.get_cmap(cmap)(256)]
        for a,label, c in zip([rna_arrays['early'], rna_arrays['late']], ['Early cells', 'Late cells'], colors):
            plt.scatter(a[:, dimensions_to_plot[0]],
                        a[:, dimensions_to_plot[1]], alpha = 0.4, label = label, color = c)

        plt.xlabel('Gene ' + str(dimensions_to_plot[0] + 1))
        plt.ylabel('Gene ' + str(dimensions_to_plot[1] + 1))
        plt.legend()
        
    # Infer ancestor locations for the late cells based on the true lineage tree
    observed_nodes = [n for n in sim_inf.get_leaves(true_trees['late, annotated'], include_root=False)]
    sim_inf.add_conditional_means_and_variances(true_trees['late, annotated'], observed_nodes)

    ancestor_info = {'true tree': sim_inf.get_ancestor_data(true_trees['late, annotated'], sample_times['early'])}
    
    # True distances
    true_distances = {key: sim_inf.compute_tree_distances(true_trees[key]) for key in true_trees}
    
    rate_estimate = sim_inf.rate_estimator(barcode_arrays['late'], sample_times['late'])

    print("Fraction unmutated barcodes: ", {key:np.sum(barcode_arrays[key] == 0)/barcode_arrays[key].size
                                            for key in barcode_arrays})
    print("Rate estimate: ", rate_estimate)
    print("True rate: ", sim_params.mutation_rate / sim_params.barcode_length)
    print("Rate accuracy: ", rate_estimate*sim_params.barcode_length/sim_params.mutation_rate)
    
    # Compute Hamming distance matrices for neighbor joining

    hamming_distances_with_roots = {
        'early': sim_inf.barcode_distances(np.concatenate([barcode_arrays['early'],
                                                           np.zeros([1,sim_params.barcode_length])])),
        'late': sim_inf.barcode_distances(np.concatenate([barcode_arrays['late'],
                                                          np.zeros([1,sim_params.barcode_length])]))
    }
    fitted_tree = sim_inf.neighbor_join(hamming_distances_with_roots['late'])
    fitted_tree_early = sim_inf.neighbor_join(hamming_distances_with_roots['early'])
    
    # Annotate fitted tree with internal node times

    sim_inf.add_leaf_barcodes(fitted_tree, barcode_arrays['late'])
    sim_inf.add_leaf_x(fitted_tree, rna_arrays['late'])
    sim_inf.add_leaf_times(fitted_tree, sample_times['late'])
    sim_inf.annotate_tree(fitted_tree,
                          rate_estimate*np.ones(sim_params.barcode_length),
                          time_inference_method = 'least_squares')
    
    # Add inferred ancestor nodes and states
    sim_inf.add_node_times_from_division_times(fitted_tree)
    sim_inf.add_nodes_at_time(fitted_tree, sample_times['early'])
    observed_nodes = [n for n in sim_inf.get_leaves(fitted_tree, include_root = False)]
    sim_inf.add_conditional_means_and_variances(fitted_tree, observed_nodes)
    ancestor_info['fitted tree'] = sim_inf.get_ancestor_data(fitted_tree, sample_times['early'])
    
    fitted_tree_distances = sim_inf.compute_tree_distances(fitted_tree)
    hamming_distances_late = hamming_distances_with_roots['late'] / rate_estimate
    
    
    sim_inf.add_leaf_barcodes(fitted_tree_early, barcode_arrays['early'])
    sim_inf.add_leaf_x(fitted_tree_early, rna_arrays['early'])
    sim_inf.add_leaf_times(fitted_tree_early, sample_times['early'])
    sim_inf.annotate_tree(fitted_tree_early,
                          rate_estimate*np.ones(sim_params.barcode_length),
                          time_inference_method = 'least_squares')
    sim_inf.add_node_times_from_division_times(fitted_tree_early)
    
    fitted_tree_early_distances = sim_inf.compute_tree_distances(fitted_tree_early)

    
    # Add inferred ancestor nodes and states
    sim_inf.add_node_times_from_division_times(fitted_tree)
    sim_inf.add_nodes_at_time(fitted_tree, sample_times['early'])

    end = perf_counter() - start
    print(f"Time: {end}")
    
    early_time_rna_cost = ot.utils.dist(rna_arrays['early'], sim_inf.extract_ancestor_data_arrays(true_trees['late'], sample_times['early'], sim_params)[0])
    late_time_rna_cost = ot.utils.dist(rna_arrays['late'], rna_arrays['late'])
    
    res = stn(sim_inf, ancestor_info, rna_arrays, true_coupling, true_distances, barcode_arrays,
              fitted_tree_early_distances, fitted_tree_distances, hamming_distances_with_roots,
              early_time_rna_cost, late_time_rna_cost, true_trees, {"early": fitted_tree_early, "late": fitted_tree})
    
    #with open(fpath, "wb") as fout:
    #    pickle.dump(tuple(res), fout)
        
    return res

# %%
def benchmark_moscot(sim: stn, *, alpha: float, epsilon: Optional[float] = None,
                     tree_type: str = 'fitted tree', scale: str = "max", **kwargs):  
    if tree_type == 'barcodes':
        e = sim_inf.barcode_distances(sim.barcode_arrays['early'])
        l = sim_inf.barcode_distances(sim.barcode_arrays['late'])
    elif tree_type == 'fitted tree':
        e = sim.fitted_tree_distances_early
        l = sim.fitted_tree_distances_late
    elif tree_type == 'true tree':
        e = sim.true_distances['early']
        l = sim.true_distances['late']
    else:
        raise NotImplementedError(tree_type)
    e = create_geometry(e, scale=scale)
    l = create_geometry(l, scale=scale)
    joint = create_geometry(ot.utils.dist(sim.rna_arrays['early'], sim.rna_arrays['late']), scale=scale)
    
    max_iterations = kwargs.pop("max_iterations", 20)
    rtol = kwargs.pop("rtol", 1e-6)
    atol = kwargs.pop("atol", 1e-6)
    
    start = perf_counter()
    if alpha == 0:
        u = Unbalanced(epsilon=epsilon)
        u.fit(joint)
        tmat = np.asarray(u.matrix)
        conv = [u.converged]
    elif alpha == 1:
        gw = GW(epsilon=epsilon)
        gw.fit(e, l)
        tmat = np.asarray(gw.matrix)
        conv = gw.converged_sinkhorn
    else:
        fgw = FusedGW(alpha=alpha, epsilon=epsilon, **kwargs)
        fgw.fit(e, l, joint, linesearch=False, verbose=False, max_iterations=max_iterations, rtol=rtol, atol=atol)
        tmat = np.asarray(fgw.matrix)
        conv = fgw.converged_sinkhorn
        
    time = perf_counter() - start
    print(f"Time: {time}")
    
    if not np.all(np.isfinite(tmat)):
        raise AssertionError("Convergence issue - not all values are finite.")
    
    early_cost = float(sim.sim_info.OT_cost(tmat, sim.early_time_rna_cost))
    late_cost = float(sim.sim_info.OT_cost(sim_eval.expand_coupling(tmat, sim.true_coupling, sim.late_time_rna_cost),
                                          sim.late_time_rna_cost))
    norm_diff = np.linalg.norm(tmat - sim.true_coupling)
        
    return bnt(tmat, early_cost, late_cost, norm_diff, conv, time)


def benchmark_lineageOT(sim: stn, *, epsilon: float, tree_type: str = 'fitted tree',  **kwargs):
    cmat = ot.utils.dist(sim.rna_arrays['early'], sim.ancestor_info[tree_type][0]) @ np.diag(sim.ancestor_info[tree_type][1] ** (-1))
    
    # Epsilon scaling is more robust at smaller epsilon, but slower than simple sinkhorn
    f = ot.sinkhorn if epsilon >= 0.1 else ot.bregman.sinkhorn_epsilon_scaling
    start = perf_counter()
    tmat = f([], [], cmat, epsilon * np.mean(sim.ancestor_info[tree_type][1] ** (-1)), **kwargs)
    time = perf_counter() - start
    
    early_cost = float(sim.sim_info.OT_cost(tmat, sim.early_time_rna_cost))
    late_cost = float(sim.sim_info.OT_cost(sim_eval.expand_coupling(tmat, sim.true_coupling, sim.late_time_rna_cost),
                                          sim.late_time_rna_cost))
    norm_diff = np.linalg.norm(tmat - sim.true_coupling)
    
    return bnt(tmat, early_cost, late_cost, norm_diff, None, time)

# %%
def gridsearch(sim: stn, *, alphas: Sequence[float], epsilons: Sequence[float], scale: str = "max", **kwargs) -> Dict[float, Dict[float, bnt]]:
    res = defaultdict(defaultdict)
    for alpha in alphas:
        for epsilon in epsilons:
            try:
                print(f"alpha={alpha}, epsilon={epsilon} scale={scale}")
                res[alpha][epsilon] = benchmark_moscot(sim, alpha=alpha, epsilon=epsilon, scale=scale, **kwargs)
            except Exception as e:
                print(traceback.format_exc())
                res[alpha][epsilon] = None
    
    return {a: {e: v for e, v in vs.items()} for a, vs in res.items()}

def gridsearch_lineageOT(sim: stn, *, epsilons: Sequence[float], **kwargs) -> Dict[float, Dict[float, bnt]]:
    res = defaultdict(defaultdict)
    for alpha in [None]:
        for epsilon in epsilons:
            if epsilon is None:
                res[alpha][epsilon] = None
                continue
            try:
                print(f"alpha={alpha}, epsilon={epsilon}")
                res[alpha][epsilon] = benchmark_lineageOT(sim, epsilon=epsilon, **kwargs)
            except Exception as e:
                print(traceback.format_exc())
                res[alpha][epsilon] = None
    
    return {a: {e: v for e, v in vs.items()} for a, vs in res.items()}

# %%
sim_params = {}
# original epsilons
epsilons = [None] + sorted([1e-4, 5e-3, 1e-3, 5e-2, 1e-2, 5e-1, 1e-1, 1])
alphas = list(np.round(np.linspace(0.0, 1, 21, dtype=np.float64), 2))
root = 'temp4'
print(epsilons)
print(alphas)
len(epsilons), len(alphas)
# Out:
# [None, 0.0001, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1]
# [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0]
# (9, 21)

# %%
# !mkdir -p $root

# %%
for flow_type in ["convergent"]:  # , "convergent", "partial_convergent", "mismatched_clusters"]:
    s = init_sim(flow_type, plot=False, **sim_params)
    break
    for kind in ['lineageOT', 'moscot']:
        for scale in ["max", "mean", "median"]:
            if kind == 'lineageOT':
                if scale != 'max':
                    continue
                fname = f"{flow_type}_lot.pickle"
                res = gridsearch_lineageOT(s, epsilons=epsilons, numItermax=100, stopThr=1e-9)
            else:
                fname = f"{flow_type}_{scale}.pickle"
                res = gridsearch(s, alphas=alphas, epsilons=epsilons, scale=scale,
                                 max_iterations=100, rtol=1e-9, atol=1e-9)

            with open(f"{root}/{fname}", "wb") as fout:
                pickle.dump(res, fout)
# Out:
# Times: {'early': 740.0, 'late': 1140.0}
# Number of cells: {'early': 64, 'late': 1024}
# Fraction unmutated barcodes:  {'early': 0.6104166666666667, 'late': 0.47311197916666664}
# Rate estimate:  0.0006565115579693221
# True rate:  0.0006666666666666666
# Rate accuracy:  0.9847673369539832
#      pcost       dcost       gap    pres   dres
#  0: -6.3033e+08 -6.5015e+08  1e+08  2e-01  2e-01
#  1: -6.2945e+08 -6.6103e+08  4e+07  4e-02  6e-02
#  2: -6.2910e+08 -6.4660e+08  2e+07  1e-02  2e-02
#  3: -6.3080e+08 -6.3880e+08  8e+06  4e-03  6e-03
#  4: -6.3112e+08 -6.3682e+08  6e+06  3e-04  5e-04
#  5: -6.3180e+08 -6.3502e+08  3e+06  1e-04  2e-04
#  6: -6.3224e+08 -6.3378e+08  2e+06  3e-05  4e-05
#  7: -6.3254e+08 -6.3282e+08  3e+05  1e-16  6e-16
#  8: -6.3260e+08 -6.3262e+08  2e+04  1e-16  3e-16
#  9: -6.3261e+08 -6.3261e+08  7e+02  1e-16  1e-15
# 10: -6.3261e+08 -6.3261e+08  3e+01  1e-16  3e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.4120e+07 -1.5437e+07  4e+06  2e-01  3e-01
#  1: -1.4205e+07 -1.4850e+07  7e+05  1e-02  2e-02
#  2: -1.4265e+07 -1.4433e+07  2e+05  1e-16  3e-16
#  3: -1.4287e+07 -1.4300e+07  1e+04  1e-16  3e-16
#  4: -1.4289e+07 -1.4290e+07  6e+02  9e-17  4e-16
#  5: -1.4289e+07 -1.4289e+07  2e+01  1e-16  3e-15
#  6: -1.4289e+07 -1.4289e+07  2e+00  1e-16  6e-14
# Optimal solution found.
# Time: 234.05340628296835

# %%
def lot_annotate(fitted_tree: nx.DiGraph, barcodes: np.ndarray, time: float, rate_estimate=None):
    sim_inf.add_leaf_barcodes(fitted_tree, barcodes)
    sim_inf.add_leaf_times(fitted_tree, time)

    # Estimating a uniform mutation rate for all target sites
    if rate_estimate is None:
        rate_estimate = sim_inf.rate_estimator(barcodes, time)
    sim_inf.annotate_tree(fitted_tree, 
                          rate_estimate*np.ones(barcodes.shape[1]),
                          time_inference_method = 'least_squares')
    
    
# root is included twice in LOT code, causes errors with NetworkX
def _internal_nodes_fixed(tree):
    """
    Returns a list of the non-leaf nodes of a tree
    """
    import inspect
    
    curframe = inspect.currentframe()
    calframe = inspect.getouterframes(curframe, 2)
    caller = calframe[1][3]
    print(caller)
    
    nodes = [node for node in tree if tree.degree(node) >= 2]
    nodes.sort(key=lambda n: "zzzzzzz" if n == 'root' else str(n))
    if caller == 'add_times':
        nodes = [n for n in nodes if n != "root"]
                
    return nodes


# monkeypatched because our tree has 'root' somehow inside and it's problematic with the sort
sim_inf.get_internal_nodes = _internal_nodes_fixed


def cassiopeia_distances(barcodes, solver='greedy', estim='mle',
                         time: float = 1.0,
                         rate_estimate=None,
                         bayesian_estimator_kwargs={},
                         hybrid_solver_kwargs={}, **kwargs):
    import cassiopeia as cas
    # pip install gurobipy  # for hybrid solver
    # if too big a problem, it raises:
    # GurobiError: Model too large for size-limited license; visit https://www.gurobi.com/free-trial for a full license
    
    n = barcodes.shape[0]
    barcodes = pd.DataFrame(barcodes, index=map(str, range(n)))
    tree = cas.data.CassiopeiaTree(character_matrix=barcodes)
    
    # for ILPSolver
    kwargs.setdefault("convergence_time_limit", 600)  # 10mins
    kwargs.setdefault("maximum_potential_graph_layer_size", 5000)
    
    if estim == 'bayesian':
        print("Setting solver to neighbor joining")
        solver = 'nj'
    
    if solver == 'nj':
        solver = cas.solver.NeighborJoiningSolver(add_root=True)
    elif solver == 'greedy':
        solver = cas.solver.VanillaGreedySolver()
    elif solver == 'ilp':
        solver = cas.solver.ILPSolver(weighted=False, seed=1234, **kwargs)
    elif solver == 'hybrid':
        ts = cas.solver.VanillaGreedySolver()
        bs = cas.solver.ILPSolver(weighted=False, seed=1234, **kwargs)
        solver = cas.solver.HybridSolver(top_solver=ts, bottom_solver=bs, **hybrid_solver_kwargs)
    else:
        raise NotImplementedError(solver)
        
    solver.solve(tree, collapse_mutationless_edges=estim != 'bayesian')
    
    if estim == 'mle':
        estim = cas.tools.branch_length_estimator.IIDExponentialMLE()
        estim.estimate_branch_lengths(tree)
    elif estim == 'bayesian':
        # root must have 1 child
        # otherwise, must be a full binary tree
        root = tree.root
        tree._CassiopeiaTree__add_node("synroot")
        tree._CassiopeiaTree__add_edge("synroot", root)
        tree._CassiopeiaTree__cache['root'] = 'synroot'
        tree.reconstruct_ancestral_characters()
        # tree.set_character_states("synroot", [])
        # tree._CassiopeiaTree__network.nodes["synroot"]['character_states'] = []
        estim = cas.tools.branch_length_estimator.IIDExponentialBayesian(**bayesian_estimator_kwargs)
        estim.estimate_branch_lengths(tree)
        tree._CassiopeiaTree__remove_node("synroot")
        tree._CassiopeiaTree__cache['root'] = root
    elif estim == 'lot':
        pass
    else:
        raise NotImplementedError(estim)
        
    G = deepcopy(tree._CassiopeiaTree__network)
    G = nx.relabel_nodes(G, dict(zip(map(str, range(n)), range(n))))
    root = [n for n in G.nodes if G.in_degree(n) == 0]
    assert len(root) == 1
    root = root[0]
    G = nx.relabel_nodes(G, {root: "root"})
    if estim == 'lot':
        lot_annotate(G, barcodes.values, time=time, rate_estimate=rate_estimate)
        return tree, G, sim_inf.compute_tree_distances(G)
    
    sim_inf.add_division_times_from_vertex_times(G, current_node='root')
    G = sim_inf.add_times_to_edges(G)
    # G = sim_inf.add_inverse_times_to_edges(G)
    
    return tree, G, sim_inf.compute_tree_distances(G)


def compare(expected: nx.DiGraph, actual: nx.DiGraph, method='triplets', **kwargs):
    from cassiopeia.data import CassiopeiaTree
    from cassiopeia.critique.compare import robinson_foulds, triplets_correct
    
    e = CassiopeiaTree()
    e.populate_tree(expected)
    a = CassiopeiaTree()
    a.populate_tree(actual)
    
    if method == 'triplets':
        score = triplets_correct(e, a, **kwargs)[0]  # all triplets correct
    elif method == 'robinson_foulds':
        score = robinson_foulds(e, a)[0]
    else:
        raise NotImplemetedError(score)
    
    return score

# %%
# int because of numba
te, Ge, ed = cassiopeia_distances(s.barcode_arrays['early'].astype(int),
                                  solver='hybrid', estim='mle',
                                  bayesian_estimator_kwargs={"mutation_rate": 0.0006666666666666666,
                                                             "birth_rate": 0.1,
                                                             "sampling_probability": 0.1},
                                  hybrid_solver_kwargs={"cell_cutoff": 40, "threads": 1})
tl, Gl, ld = cassiopeia_distances(s.barcode_arrays['late'].astype(int),
                                  solver='hybrid', estim='mle',
                                  bayesian_estimator_kwargs={"mutation_rate": 0.0006666666666666666,
                                                             "birth_rate": 0.1,
                                                             "sampling_probability": 0.1},
                                  hybrid_solver_kwargs={"cell_cutoff": 40, "threads": 1})
# Out:
# [2021-10-07 22:39:27,344]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:27,346]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:27,347]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:27,348]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:27,349]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:27,349]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:27,734]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 16.
# [2021-10-07 22:39:27,761]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 0 completed with a neighborhood size of 19.
# [2021-10-07 22:39:27,788]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 1 completed with a neighborhood size of 19.
# [2021-10-07 22:39:27,814]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 2 completed with a neighborhood size of 19.
# [2021-10-07 22:39:27,844]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 3 completed with a neighborhood size of 19.
# [2021-10-07 22:39:27,875]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 4 completed with a neighborhood size of 19.
# [2021-10-07 22:39:27,907]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 5 completed with a neighborhood size of 19.
# [2021-10-07 22:39:27,938]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 6 completed with a neighborhood size of 19.
# [2021-10-07 22:39:27,970]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 7 completed with a neighborhood size of 19.
# [2021-10-07 22:39:28,003]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 8 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,030]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 9 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,056]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 10 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,084]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 11 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,111]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 12 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,140]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 13 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,169]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 14 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,197]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 15 completed with a neighborhood size of 20.
# [2021-10-07 22:39:28,227]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 16 completed with a neighborhood size of 20.
# Restricted license - for non-production use only - expires 2022-01-13
# [2021-10-07 22:39:28,263]    INFO [ILPSolver] (Process c630189011a0f01e0d3cd835abe74843) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:28,277]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:28,279]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:28,280]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:28,280]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:28,281]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:28,282]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:28,285]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 16.
# [2021-10-07 22:39:28,312]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 0 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,342]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 1 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,372]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 2 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,404]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 3 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,429]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 4 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,449]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 5 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,473]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 6 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,502]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 7 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,532]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 8 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,563]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 9 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,594]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 10 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,617]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 11 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,638]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 12 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,658]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 13 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,679]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 14 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,702]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 15 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,730]    INFO [ILPSolver] (Process: c078a0191a47d693be6b275cdcbbbc35) LCA distance 16 completed with a neighborhood size of 16.
# [2021-10-07 22:39:28,747]    INFO [ILPSolver] (Process c078a0191a47d693be6b275cdcbbbc35) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
#   0%|          | 0/2 [00:00<?, ?it/s]
# [2021-10-07 22:39:30,453]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:30,456]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:30,456]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:30,457]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:30,458]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:30,459]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:30,731]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 10.
# [2021-10-07 22:39:30,742]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 0 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,753]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 1 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,764]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 2 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,775]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 3 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,785]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 4 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,794]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 5 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,804]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 6 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,814]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 7 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,825]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 8 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,836]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 9 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,847]    INFO [ILPSolver] (Process: 6c5979b4369a18d48dc2798602b14bce) LCA distance 10 completed with a neighborhood size of 9.
# Restricted license - for non-production use only - expires 2022-01-13
# [2021-10-07 22:39:30,876]    INFO [ILPSolver] (Process 6c5979b4369a18d48dc2798602b14bce) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:30,887]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:30,888]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:30,888]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:30,889]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:30,890]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:30,891]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:30,894]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 9.
# [2021-10-07 22:39:30,905]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 0 completed with a neighborhood size of 8.
# [2021-10-07 22:39:30,914]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 1 completed with a neighborhood size of 8.
# [2021-10-07 22:39:30,924]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 2 completed with a neighborhood size of 8.
# [2021-10-07 22:39:30,935]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 3 completed with a neighborhood size of 8.
# [2021-10-07 22:39:30,944]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 4 completed with a neighborhood size of 8.
# [2021-10-07 22:39:30,955]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 5 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,969]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 6 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,983]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 7 completed with a neighborhood size of 9.
# [2021-10-07 22:39:30,998]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 8 completed with a neighborhood size of 9.
# [2021-10-07 22:39:31,011]    INFO [ILPSolver] (Process: 3c9e490c6cb5d92b5465796566a4ddcb) LCA distance 9 completed with a neighborhood size of 9.
# [2021-10-07 22:39:31,020]    INFO [ILPSolver] (Process 3c9e490c6cb5d92b5465796566a4ddcb) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:31,035]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:31,036]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:31,036]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:31,037]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:31,038]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:31,039]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:31,043]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 12.
# [2021-10-07 22:39:31,070]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 0 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,100]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 1 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,127]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 2 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,159]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 3 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,193]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 4 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,227]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 5 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,269]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 6 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,304]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 7 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,332]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 8 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,368]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 9 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,396]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 10 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,438]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 11 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,483]    INFO [ILPSolver] (Process: 775c71497500b4ee486518fa9ca77b58) LCA distance 12 completed with a neighborhood size of 14.
# [2021-10-07 22:39:31,502]    INFO [ILPSolver] (Process 775c71497500b4ee486518fa9ca77b58) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:31,524]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:31,526]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:31,526]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:31,527]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:31,528]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:31,529]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:31,534]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 15.
# [2021-10-07 22:39:31,576]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 0 completed with a neighborhood size of 17.
# [2021-10-07 22:39:31,614]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 1 completed with a neighborhood size of 17.
# [2021-10-07 22:39:31,652]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 2 completed with a neighborhood size of 17.
# [2021-10-07 22:39:31,690]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 3 completed with a neighborhood size of 17.
# [2021-10-07 22:39:31,728]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 4 completed with a neighborhood size of 17.
# [2021-10-07 22:39:31,767]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 5 completed with a neighborhood size of 17.
# [2021-10-07 22:39:31,805]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 6 completed with a neighborhood size of 17.
# [2021-10-07 22:39:31,844]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 7 completed with a neighborhood size of 18.
# [2021-10-07 22:39:31,884]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 8 completed with a neighborhood size of 18.
# [2021-10-07 22:39:31,932]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 9 completed with a neighborhood size of 18.
# [2021-10-07 22:39:31,981]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 10 completed with a neighborhood size of 18.
# [2021-10-07 22:39:32,049]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 11 completed with a neighborhood size of 18.
# [2021-10-07 22:39:32,097]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 12 completed with a neighborhood size of 18.
# [2021-10-07 22:39:32,137]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 13 completed with a neighborhood size of 18.
# [2021-10-07 22:39:32,176]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 14 completed with a neighborhood size of 18.
# [2021-10-07 22:39:32,218]    INFO [ILPSolver] (Process: 03ef62a16310ca82129add6c2faf6226) LCA distance 15 completed with a neighborhood size of 18.
# [2021-10-07 22:39:32,233]    INFO [ILPSolver] (Process 03ef62a16310ca82129add6c2faf6226) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:32,252]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:32,254]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:32,254]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:32,255]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:32,255]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:32,256]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:32,259]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 8.
# [2021-10-07 22:39:32,263]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 0 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,267]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 1 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,271]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 2 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,275]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 3 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,279]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 4 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,283]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 5 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,287]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 6 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,290]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 7 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,294]    INFO [ILPSolver] (Process: a5fcccd7acb7e626f92928f9e1abb0df) LCA distance 8 completed with a neighborhood size of 4.
# [2021-10-07 22:39:32,299]    INFO [ILPSolver] (Process a5fcccd7acb7e626f92928f9e1abb0df) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:32,308]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:32,308]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:32,309]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:32,310]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:32,311]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:32,312]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:32,318]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 14.
# [2021-10-07 22:39:32,355]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 0 completed with a neighborhood size of 15.
# [2021-10-07 22:39:32,386]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 1 completed with a neighborhood size of 15.
# [2021-10-07 22:39:32,417]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 2 completed with a neighborhood size of 15.
# [2021-10-07 22:39:32,449]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 3 completed with a neighborhood size of 15.
# [2021-10-07 22:39:32,481]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 4 completed with a neighborhood size of 15.
# [2021-10-07 22:39:32,519]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 5 completed with a neighborhood size of 15.
# [2021-10-07 22:39:32,557]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 6 completed with a neighborhood size of 15.
# [2021-10-07 22:39:32,599]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 7 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,640]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 8 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,681]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 9 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,720]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 10 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,761]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 11 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,810]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 12 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,844]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 13 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,881]    INFO [ILPSolver] (Process: 07ad602d00480ce712b613aa8fe8db77) LCA distance 14 completed with a neighborhood size of 16.
# [2021-10-07 22:39:32,893]    INFO [ILPSolver] (Process 07ad602d00480ce712b613aa8fe8db77) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:32,910]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:32,911]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:32,912]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:32,913]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:32,914]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:32,915]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:32,919]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 12.
# [2021-10-07 22:39:32,957]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 0 completed with a neighborhood size of 15.
# [2021-10-07 22:39:33,001]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 1 completed with a neighborhood size of 15.
# [2021-10-07 22:39:33,032]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 2 completed with a neighborhood size of 15.
# [2021-10-07 22:39:33,067]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 3 completed with a neighborhood size of 15.
# [2021-10-07 22:39:33,095]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 4 completed with a neighborhood size of 15.
# [2021-10-07 22:39:33,137]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 5 completed with a neighborhood size of 15.
# [2021-10-07 22:39:33,192]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 6 completed with a neighborhood size of 16.
# [2021-10-07 22:39:33,237]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 7 completed with a neighborhood size of 16.
# [2021-10-07 22:39:33,281]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 8 completed with a neighborhood size of 16.
# [2021-10-07 22:39:33,318]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 9 completed with a neighborhood size of 16.
# [2021-10-07 22:39:33,353]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 10 completed with a neighborhood size of 16.
# [2021-10-07 22:39:33,391]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 11 completed with a neighborhood size of 16.
# [2021-10-07 22:39:33,420]    INFO [ILPSolver] (Process: 72820f0f5662fda01683300d7364ac17) LCA distance 12 completed with a neighborhood size of 16.
# [2021-10-07 22:39:33,431]    INFO [ILPSolver] (Process 72820f0f5662fda01683300d7364ac17) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:33,447]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:33,448]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:33,449]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:33,450]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:33,451]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:33,452]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:33,456]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 16.
# [2021-10-07 22:39:33,498]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 0 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,541]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 1 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,597]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 2 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,656]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 3 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,712]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 4 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,756]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 5 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,809]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 6 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,870]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 7 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,929]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 8 completed with a neighborhood size of 21.
# [2021-10-07 22:39:33,991]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 9 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,064]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 10 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,110]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 11 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,152]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 12 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,200]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 13 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,240]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 14 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,280]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 15 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,337]    INFO [ILPSolver] (Process: f96853ab5a1ff31e7d91b093e7eb0ccd) LCA distance 16 completed with a neighborhood size of 21.
# [2021-10-07 22:39:34,364]    INFO [ILPSolver] (Process f96853ab5a1ff31e7d91b093e7eb0ccd) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:34,386]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:34,387]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:34,388]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:34,389]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:34,390]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:34,391]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:34,395]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 16.
# [2021-10-07 22:39:34,435]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 0 completed with a neighborhood size of 19.
# [2021-10-07 22:39:34,472]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 1 completed with a neighborhood size of 19.
# [2021-10-07 22:39:34,512]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 2 completed with a neighborhood size of 19.
# [2021-10-07 22:39:34,560]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 3 completed with a neighborhood size of 19.
# [2021-10-07 22:39:34,616]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 4 completed with a neighborhood size of 19.
# [2021-10-07 22:39:34,671]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 5 completed with a neighborhood size of 19.
# [2021-10-07 22:39:34,725]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 6 completed with a neighborhood size of 19.
# [2021-10-07 22:39:34,789]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 7 completed with a neighborhood size of 20.
# [2021-10-07 22:39:34,832]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 8 completed with a neighborhood size of 20.
# [2021-10-07 22:39:34,885]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 9 completed with a neighborhood size of 20.
# [2021-10-07 22:39:34,946]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 10 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,009]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 11 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,059]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 12 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,098]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 13 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,147]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 14 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,194]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 15 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,256]    INFO [ILPSolver] (Process: 06663cd365c761ea6f0179eaa063784c) LCA distance 16 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,282]    INFO [ILPSolver] (Process 06663cd365c761ea6f0179eaa063784c) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:35,301]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:35,302]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:35,303]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:35,304]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:35,304]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:35,305]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:35,309]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 19.
# [2021-10-07 22:39:35,366]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 0 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,431]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 1 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,482]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 2 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,537]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 3 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,593]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 4 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,639]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 5 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,686]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 6 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,733]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 7 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,783]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 8 completed with a neighborhood size of 20.
# [2021-10-07 22:39:35,829]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 9 completed with a neighborhood size of 21.
# [2021-10-07 22:39:35,877]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 10 completed with a neighborhood size of 22.
# [2021-10-07 22:39:35,925]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 11 completed with a neighborhood size of 22.
# [2021-10-07 22:39:35,973]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 12 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,021]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 13 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,069]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 14 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,121]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 15 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,184]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 16 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,252]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 17 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,316]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 18 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,378]    INFO [ILPSolver] (Process: d60952ad71652eb0c10a6fbf5e7cfad0) LCA distance 19 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,404]    INFO [ILPSolver] (Process d60952ad71652eb0c10a6fbf5e7cfad0) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:36,428]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:36,429]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:36,430]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:36,431]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:36,432]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:36,432]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:36,437]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 13.
# [2021-10-07 22:39:36,485]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 0 completed with a neighborhood size of 20.
# [2021-10-07 22:39:36,533]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 1 completed with a neighborhood size of 20.
# [2021-10-07 22:39:36,582]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 2 completed with a neighborhood size of 20.
# [2021-10-07 22:39:36,633]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 3 completed with a neighborhood size of 21.
# [2021-10-07 22:39:36,683]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 4 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,734]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 5 completed with a neighborhood size of 22.
# [2021-10-07 22:39:36,776]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 6 completed with a neighborhood size of 23.
# [2021-10-07 22:39:36,813]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 7 completed with a neighborhood size of 23.
# [2021-10-07 22:39:36,852]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 8 completed with a neighborhood size of 23.
# [2021-10-07 22:39:36,893]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 9 completed with a neighborhood size of 23.
# [2021-10-07 22:39:36,930]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 10 completed with a neighborhood size of 23.
# [2021-10-07 22:39:36,969]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 11 completed with a neighborhood size of 23.
# [2021-10-07 22:39:37,008]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 12 completed with a neighborhood size of 23.
# [2021-10-07 22:39:37,049]    INFO [ILPSolver] (Process: c2c9c9df2fa5ea4415f45fed6100df7a) LCA distance 13 completed with a neighborhood size of 23.
# [2021-10-07 22:39:37,182]    INFO [ILPSolver] (Process c2c9c9df2fa5ea4415f45fed6100df7a) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:37,204]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:37,205]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:37,206]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:37,206]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:37,207]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:37,208]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:37,212]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 11.
# [2021-10-07 22:39:37,245]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 0 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,274]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 1 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,302]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 2 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,331]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 3 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,361]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 4 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,391]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 5 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,420]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 6 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,448]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 7 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,478]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 8 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,508]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 9 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,538]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 10 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,567]    INFO [ILPSolver] (Process: e3ddd210ee3a45202f9a9a37798658a1) LCA distance 11 completed with a neighborhood size of 15.
# [2021-10-07 22:39:37,579]    INFO [ILPSolver] (Process e3ddd210ee3a45202f9a9a37798658a1) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:37,593]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:37,595]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:37,595]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:37,596]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:37,596]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:37,599]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:37,602]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 13.
# [2021-10-07 22:39:37,632]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 0 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,663]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 1 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,691]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 2 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,721]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 3 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,752]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 4 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,783]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 5 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,818]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 6 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,859]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 7 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,901]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 8 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,933]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 9 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,964]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 10 completed with a neighborhood size of 17.
# [2021-10-07 22:39:37,995]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 11 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,027]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 12 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,059]    INFO [ILPSolver] (Process: 505e9b94521fe1a681cad814a9456352) LCA distance 13 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,073]    INFO [ILPSolver] (Process 505e9b94521fe1a681cad814a9456352) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:38,088]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:38,090]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:38,090]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:38,091]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:38,091]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:38,092]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:38,095]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 13.
# [2021-10-07 22:39:38,129]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 0 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,170]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 1 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,212]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 2 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,254]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 3 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,285]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 4 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,313]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 5 completed with a neighborhood size of 17.
# [2021-10-07 22:39:38,344]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 6 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,375]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 7 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,405]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 8 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,438]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 9 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,471]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 10 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,504]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 11 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,538]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 12 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,569]    INFO [ILPSolver] (Process: 5f16a90d331544d6b4a051f8532d76fd) LCA distance 13 completed with a neighborhood size of 18.
# [2021-10-07 22:39:38,584]    INFO [ILPSolver] (Process 5f16a90d331544d6b4a051f8532d76fd) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:38,601]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:38,602]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:38,603]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:38,604]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:38,605]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:38,605]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:38,609]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 14.
# [2021-10-07 22:39:38,639]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 0 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,671]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 1 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,703]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 2 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,736]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 3 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,769]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 4 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,802]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 5 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,835]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 6 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,868]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 7 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,901]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 8 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,934]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 9 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,967]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 10 completed with a neighborhood size of 15.
# [2021-10-07 22:39:38,999]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 11 completed with a neighborhood size of 15.
# [2021-10-07 22:39:39,033]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 12 completed with a neighborhood size of 15.
# [2021-10-07 22:39:39,067]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 13 completed with a neighborhood size of 15.
# [2021-10-07 22:39:39,100]    INFO [ILPSolver] (Process: 378a16e24e5dd7ee2dfe9439e6b7617d) LCA distance 14 completed with a neighborhood size of 15.
# [2021-10-07 22:39:39,114]    INFO [ILPSolver] (Process 378a16e24e5dd7ee2dfe9439e6b7617d) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:39,131]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:39,132]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:39,133]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:39,133]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:39,134]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:39,135]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:39,138]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 12.
# [2021-10-07 22:39:39,153]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 0 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,170]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 1 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,188]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 2 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,204]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 3 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,224]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 4 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,241]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 5 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,259]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 6 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,279]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 7 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,297]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 8 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,314]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 9 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,333]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 10 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,351]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 11 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,370]    INFO [ILPSolver] (Process: e50d27a386042d2542a81e577ed6b2a3) LCA distance 12 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,377]    INFO [ILPSolver] (Process e50d27a386042d2542a81e577ed6b2a3) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:39,389]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:39,390]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:39,391]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:39,392]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:39,392]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:39,393]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:39,396]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 13.
# [2021-10-07 22:39:39,426]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 0 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,457]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 1 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,489]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 2 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,523]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 3 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,560]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 4 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,605]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 5 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,650]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 6 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,695]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 7 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,731]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 8 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,763]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 9 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,795]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 10 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,828]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 11 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,862]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 12 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,897]    INFO [ILPSolver] (Process: 2f8c2ae545da4d46b9c56d50780acf8e) LCA distance 13 completed with a neighborhood size of 20.
# [2021-10-07 22:39:39,913]    INFO [ILPSolver] (Process 2f8c2ae545da4d46b9c56d50780acf8e) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:39,928]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:39,929]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:39,930]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:39,931]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:39,931]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:39,932]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:39,934]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 9.
# [2021-10-07 22:39:39,945]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 0 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,955]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 1 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,967]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 2 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,981]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 3 completed with a neighborhood size of 9.
# [2021-10-07 22:39:39,995]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 4 completed with a neighborhood size of 9.
# [2021-10-07 22:39:40,011]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 5 completed with a neighborhood size of 9.
# [2021-10-07 22:39:40,026]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 6 completed with a neighborhood size of 9.
# [2021-10-07 22:39:40,039]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 7 completed with a neighborhood size of 9.
# [2021-10-07 22:39:40,051]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 8 completed with a neighborhood size of 9.
# [2021-10-07 22:39:40,065]    INFO [ILPSolver] (Process: 454fae800cebc48490e4deef0fa4848e) LCA distance 9 completed with a neighborhood size of 9.
# [2021-10-07 22:39:40,074]    INFO [ILPSolver] (Process 454fae800cebc48490e4deef0fa4848e) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
# [2021-10-07 22:39:40,087]    INFO [ILPSolver] Solving tree with the following parameters.
# [2021-10-07 22:39:40,088]    INFO [ILPSolver] Convergence time limit: 600
# [2021-10-07 22:39:40,089]    INFO [ILPSolver] Convergence iteration limit: 0
# [2021-10-07 22:39:40,090]    INFO [ILPSolver] Max potential graph layer size: 5000
# [2021-10-07 22:39:40,091]    INFO [ILPSolver] Max potential graph lca distance: None
# [2021-10-07 22:39:40,091]    INFO [ILPSolver] MIP gap: 0.01
# [2021-10-07 22:39:40,095]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) Estimating a potential graph with a maximum layer size of 5000 and a maximum LCA distance of 11.
# [2021-10-07 22:39:40,109]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 0 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,122]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 1 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,135]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 2 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,148]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 3 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,161]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 4 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,175]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 5 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,191]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 6 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,207]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 7 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,227]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 8 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,244]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 9 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,260]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 10 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,274]    INFO [ILPSolver] (Process: c630189011a0f01e0d3cd835abe74843) LCA distance 11 completed with a neighborhood size of 13.
# [2021-10-07 22:39:40,281]    INFO [ILPSolver] (Process c630189011a0f01e0d3cd835abe74843) Steiner tree solving tool 0 days, 0 hours, 0 minutes, and 0 seconds.
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
scale = 'max'
alpha = 0.95
epsilon = 1e-4
edg = create_geometry(ed, scale=scale)
ldg = create_geometry(ld, scale=scale)
joint = create_geometry(ot.utils.dist(s.rna_arrays['early'], s.rna_arrays['late']), scale=scale)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
fgw = FusedGW(alpha=alpha, epsilon=epsilon)
fgw.fit(edg, ldg, joint, rtol=1e-9, atol=1e-9, max_iterations=100, linesearch=False)
tmat = np.asarray(fgw.matrix)
early_cost = float(s.sim_info.OT_cost(tmat, s.early_time_rna_cost))
late_cost = float(s.sim_info.OT_cost(sim_eval.expand_coupling(tmat, s.true_coupling, s.late_time_rna_cost),
                                     s.late_time_rna_cost))
early_cost, late_cost
# Out:
# It.  |Loss        |Rel. loss   |Abs. loss   |tau         |converged   |eps
# -----------------------------------------------------------------------------------
#     1|1.970856e-01|1.000000e+00|1.970856e-01|1.000000e+00|           1|1.000000e-04
#     2|1.623780e-01|2.137460e-01|3.470765e-02|1.000000e+00|           0|1.000000e-04
#     3|1.133211e-01|4.329013e-01|4.905686e-02|1.000000e+00|           0|1.000000e-04
#     4|1.091192e-01|3.850810e-02|4.201971e-03|1.000000e+00|           0|1.000000e-04
#     5|1.080395e-01|9.992790e-03|1.079616e-03|1.000000e+00|           0|1.000000e-04
#     6|1.009051e-01|7.070472e-02|7.134465e-03|1.000000e+00|           0|1.000000e-04
#     7|8.228030e-02|2.263576e-01|1.862477e-02|1.000000e+00|           1|1.000000e-04
#     8|8.166771e-02|7.500964e-03|6.125866e-04|1.000000e+00|           1|1.000000e-04
#     9|8.108899e-02|7.136866e-03|5.787212e-04|1.000000e+00|           1|1.000000e-04
#    10|8.010560e-02|1.227616e-02|9.833890e-04|1.000000e+00|           1|1.000000e-04
#    11|8.009228e-02|1.662760e-04|1.331742e-05|1.000000e+00|           1|1.000000e-04
#    12|8.009206e-02|2.744805e-06|2.198371e-07|1.000000e+00|           1|1.000000e-04
#    13|8.009178e-02|3.534550e-06|2.830884e-07|1.000000e+00|           1|1.000000e-04
#    14|8.009124e-02|6.740689e-06|5.398702e-07|1.000000e+00|           1|1.000000e-04
#    15|8.009101e-02|2.855879e-06|2.287302e-07|1.000000e+00|           1|1.000000e-04
#    16|8.009056e-02|5.576416e-06|4.466183e-07|1.000000e+00|           1|1.000000e-04
#    17|8.008830e-02|2.828171e-05|2.265034e-06|1.000000e+00|           1|1.000000e-04
#    18|8.003294e-02|6.917317e-04|5.536132e-05|1.000000e+00|           1|1.000000e-04
#    19|8.001278e-02|2.519769e-04|2.016137e-05|1.000000e+00|           1|1.000000e-04
#    20|8.001260e-02|2.191907e-06|1.753802e-07|1.000000e+00|           1|1.000000e-04
#    21|8.001260e-02|5.598282e-08|4.479331e-09|1.000000e+00|           1|1.000000e-04
#    22|8.001261e-02|2.252115e-08|1.801976e-09|1.000000e+00|           1|1.000000e-04
#    23|8.001261e-02|8.083891e-09|6.468132e-10|1.000000e+00|           1|1.000000e-04
# (0.10759850631779352, 0.44865009549816776)
